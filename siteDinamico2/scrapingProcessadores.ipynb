# %%
# modulo para controlar o navegador web
from selenium import webdriver

#localizador de elementos
from selenium.webdriver.common.by import By

# serviço para configurar o caminho do executavel chomedriver
from selenium.webdriver.chrome.service import Service

# classe que permite executar ações avançadas( o mover do mouse, clique/arrasta
from selenium.webdriver.common.action_chains import ActionChains

# classe que espera de forma explicita ate que uma condicao seja satisfeita (ex: que um elemento apareça)
from selenium.webdriver.support.ui import WebDriverWait

# condicoes esperadas usadas com webDriveWait
from selenium.webdriver.support import expected_conditions as ec

# trabalha com dataframes
import pandas as pd

# uso de funções relacionados ao tempos
import time 

# definir caminho do chomedriver
from selenium.common.exceptions import TimeoutException

# inicialização do webDriver

chrome_driver_path = "C:\Program Files\chromedriver-win64\chromedriver-win64\chromedriver.exe"

# configuracao do webDriver
servico = Service(chrome_driver_path) #navegador controlado pelo selenium
controle = webdriver.ChromeOptions() #configurar opcoes do navegador
controle.add_argument("--disable-gpu") #evita erros graficos
controle.add_argument("--window-size=1920,1080") #define uma resolução simples

#inicialização do webDriver
driver = webdriver.Chrome(service=servico, options=controle)

# URl inicial
url_base ="https://www.kabum.com.br/hardware/processadores/processador-intel"
driver.get(url_base)
time.sleep(5) #aguarda 5 segundos para garantir que a pagina carregue 


#criar um dicionario para armazenar os nomes e preços dasa cadeiras 
dick_produtos = {"marca":[], "preço":[]}

#inicia uma pagina, pagina 1 e incrementamos a cada troca de pagina 
pagina = 1

while True:
    print(f"\n coletandos dados da pagina{pagina}...")
    try:
        WebDriverWait(driver, 10).until(
            ec.presence_of_all_elements_located((By.CLASS_NAME,"productCard"))
            )
        print("Elementos encontrados com sucesso!")
    except TimeoutException:
        print("Tempo de espera excedido!")
        
    produtos = driver.find_elements(By.CLASS_NAME,"productCard")
    
    for produto in produtos:
        try:
            nome = produto.find_element(By.CLASS_NAME, "nameCard").text.strip()
            preco = produto.find_element(By.CLASS_NAME, "priceCard").text.strip()
            parcelas = produto.find_element(By.CLASS_NAME, "text-xs")
            print(f"{nome} - {preco}")
             
            dick_produtos["marca"].append(nome)
            dick_produtos["preço"].append(preco)
            
            
        except Exception:
            print("Erro ao coletar dados:", Exception)
            
# encontrar botão da proxima pagina
    try:
        # encontrar o elemento 
        botao_proximo = WebDriverWait(driver, 5).until(
            ec.element_to_be_clickable((By.CLASS_NAME, "nextLink"))
        )
        if botao_proximo:
            driver.execute_script("arguments[0].scrollIntoView();", botao_proximo)
            time.sleep(1)
            
            # clicar no botão
            driver.execute_script("arguments[0].click();", botao_proximo)
            print(f"indo para a pagina {pagina}")
            pagina += 1 
            
            time.sleep(5)
        
        else:
            print("você chegou na ultima pagina!")
            break
        
    except Exception as e :
        print("Erro a tentar avançar para a proxima página", e)
        break
    

# fecha o navegador
driver.quit()

df = pd.DataFrame(dick_produtos)
df.to_excel("processadores.xlsx", index=False)


print("Arquivo 'processadores' salvo com sucesso ({len(df)} produtos capturados!)")
# Out:
# <>:30: SyntaxWarning: invalid escape sequence '\P'
# <>:30: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\44581098807\AppData\Local\Temp\ipykernel_18152\3823860488.py:30: SyntaxWarning: invalid escape sequence '\P'
#   chrome_driver_path = "C:\Program Files\chromedriver-win64\chromedriver-win64\chromedriver.exe"
#  coletandos dados da pagina1...
# Elementos encontrados com sucesso!
# Processador Intel Core i5-12400F, 2.5GHz (4.4GHz Max Turbo), Cache 18MB, LGA 1700 - BX8071512400F - R$ 749,99
# Processador Intel Core i5-12400, 2.5GHz (4.4GHz Max Turbo), Cache 18MB, LGA 1700 - BX8071512400 - R$ 1.099,99
# Processador Intel Core i5-14600K, 14ª Geração, 5.3 GHz Max Turbo, Cache 24MB, 14 Núcleos, 20 Threads, LGA1700 - BX8071514600K - R$ 1.749,99
# Processador Intel Core i3-10105, 3.7GHz (4.4GHz Max Turbo), Cache 6MB, Quad Core, 8 Threads, LGA 1200, Vídeo Integrado - BX8070110105 - R$ 649,99
# Processador Intel Core i5-10400F, 2.9GHz (4.3GHz Max Turbo), Cache 12MB, 6 Núcleos, 12 Threads, LGA 1200 - BX8070110400F - R$ 749,99
# Processador Intel Core i7-12700K, 3.6GHz (5.0GHz Max Turbo), 12 Núcleos, 20 Threads, LGA 1700, Vídeo Integrado - BX8071512700K - R$ 1.839,99
# Processador Intel I3-10105F, 3.7GHz, Cache 6MB, Quad Core, 8 Threads, LGA 1200 - BX8070110105F - R$ 528,97
# Processador Intel Core i9-14900K, 14ª Geração, 6GHz Max Turbo, Cache 36MB, 24 Núcleos, 32 Threads, LGA1700 - BX8071514900K - R$ 3.249,99
# Processador Intel Core i7-14700K, 14ª Geração, 5.6 GHz Max Turbo, Cache 33MB, 20 Núcleos, 28 Threads, LGA1700 - BX8071514700K - R$ 2.899,99
# Processador Intel Core i7-14700KF, 14ª Geração, 5.6 GHz Max Turbo, Cache 33MB, 20 Núcleos, 28 Threads, LGA1700 - BX8071514700KF - R$ 2.539,99
# Processador Intel Core i7-12700F, 2.1GHz (4.9GHz Max Turbo), Cache 25MB, LGA 1700 - BX8071512700F - R$ 1.699,99
# Processador Intel Core i9-14900KF, 14ª Geração, 6GHz Max Turbo, Cache 36MB, 24 Núcleos, 32 Threads, LGA1700 - BX8071514900KF - R$ 3.199,99
# Processador Intel Core I5 14400f 14ª Geração, 3.5 Ghz (4.7 Ghz Turbo), Cache 20mb, 10 Núcleos, 16 Threads, Lga1700, Sem Vídeo Integrado - Bx8071514400f - R$ 1.051,69
# Processador Intel Core i9-12900KS, 3.4GHz (5.5GHz Max Turbo), Cache 30MB, LGA 1700, Vídeo Integrado - BX8071512900KS - R$ 2.249,99
# Processador Intel Core i7-12700KF, 3.6GHz (5.0GHz Max Turbo), Cache 25MB, 12 Núcleos, 20 Threads, LGA 1700 - BX8071512700KF - R$ 1.549,99
# Processador Intel Core i5-10400, 2.9GHz (4.3GHz Max Turbo), Cache 12MB, LGA 1200 - BX8070110400 - R$ 949,99
# Processador Intel Core i5-12600KF, 3.7GHz (4.9Ghz Max Turbo), Cache 20MB, Quad Core, 16 Threads, LGA 1700 - BX8071512600KF - R$ 1.199,99
# Processador Intel Core i5-13400F, 4.6GHz Max Turbo, Cache 20MB, 10 Núcleos, 16 Threads, LGA 1700 - BX8071513400F - R$ 1.199,99
# Processador Intel Core I3-10100, 3.60GHz (4.3GHz Turbo), Cache 6MB, LGA 1200 - BX8070110100 - R$ 679,00
# Processador Intel Core i5-14600KF, 14ª Geração, 5.3 GHz Max Turbo, Cache 24MB, 14 Núcleos, 20 Threads, LGA1700 - BX8071514600KF - R$ 1.599,99
# indo para a pagina 1
#
#  coletandos dados da pagina2...
# Elementos encontrados com sucesso!
# Processador Intel Core I5 - 12400F, 2.5GHz (4.4GHz Turbo), Cache 7,5MB, 12 Threads, Hexa Core, LGA 1700 - BX8071512400F - R$ 769,00
# Processador Intel Core I5 14600kf 14 Geração, 3.5 Ghz (5.3 Ghz Turbo), Cache 24MP, LGA1700 - Bx8071514600kf - R$ 2.299,00
# Processador Intel Core i3-13100, 4.5GHz Max Turbo, Cache 12MB, 4 Núcleos, 8 Threads, LGA 1700, Vídeo Integrado - BX8071513100 - R$ 849,99
# Processador Intel Core i3-12100F, 3.3GHz (4.3GHz Max Turbo), Cache 12MB, LGA 1700 - BX8071512100F - R$ 549,99
# Processador Intel Core i3-12100, Cache 12MB, 3.3GHz (4.3GHz Max Turbo), LGA 1700, Vídeo Integrado, com Cooler - BX8071512100 - R$ 849,99
# Processador Intel Core i5-13400, 4.6GHz Max Turbo, Cache 20MB, 10 Núcleos, 16 Threads, LGA 1700, Vídeo Integrado - BX8071513400 - R$ 1.399,99
# Processador Intel Core i9-12900KF, 3.2GHz (5.2GHz Max Turbo), Cache 30MB, 16 Núcleos, 24 Threads, LGA 1700 - BX8071512900KF - R$ 2.299,99
# Processador Intel Pentium Gold G6400 Processor, 4.00 GHz, Cache 4MB, Dual Core, 4 Threads, LGA1200 - BX80701G6400 - R$ 519,99
# Processador Intel Core i7-12700, Cache 25MB, 2.1GHz (4.9GHz Max Turbo), LGA 1700 - BX8071512700 - R$ 1.819,99
# Processador Intel Core i5-12600K, 3.7GHz (4.9GHz Max Turbo), Cache 20MB, 10 Núcleos, 16 Threads, LGA 1700, Vídeo Integrado - BX8071512600K - R$ 1.299,99
# Processador Intel Core i9-12900F, Cache 30MB, 2.4GHz (5.1GHz Max Turbo), LGA 1700 - BX8071512900F - R$ 2.159,99
# Processador Intel Core i7-13700F, 5.2GHz Max Turbo, Cache 30MB, 16 Núcleos, 24 Threads, LGA 1700 - BX8071513700F - R$ 2.299,99
# Processador Intel Core i3-10100F, 3.6GHz (4.3GHz Max Boost), Cache 6MB, Quad Core, 8 Threads, LGA 1200 - BX8070110100F - R$ 499,99
# Processador Intel Core i9-13900F, 5.6GHz Max Turbo, Cache 36MB, 24 Núcleos, 32 Threads, LGA 1700 - BX8071513900F - R$ 2.949,99
# Processador Intel Core I3 - 14100, 3.5 GHz, (4.7GHz Turbo), Cache 12MB, 8 Threads, LGA 1700 - Bx8071514100 - R$ 876,40
# Processador Intel Core I7-14700f, Turbo Até 5.4ghz, 20-cores, 28-threads, 33mb Cache, LGA 1700 - Bx8071514700f - R$ 2.442,00
# Processador Intel Celeron G5905, 3.50 GHz, Cache 4MB, 2 Núcleos, 2 Threads, LGA 1200, Vídeo Integrado - BX80701G5905 - R$ 329,99
# Processador Intel Pentium Gold G6405, 4.10 GHz, Cache 4MB, Dual Core, 4 Threads, LGA1200 - BX80701G6405 - R$ 529,99
# Processador Intel Core I5 14400, 14ª Geração 3.5 Ghz, 4.7 Ghz Turbo, Cache 20mb, LGA1700 - Bx8071514400 - R$ 1.303,85
# Processador Intel Core I5 13400f, 2.5GHz (4.6GHz Turbo), Cache 20MB, 10 Núcleos, 16 Threads, LGA 1700, Sem Vídeo - Bx8071513400f - R$ 979,00
# indo para a pagina 2
#
#  coletandos dados da pagina3...
# Elementos encontrados com sucesso!
# Processador Intel I7-12700KF, 3.6GHz 5.0GHz Max Turbo, Cache 25MB, Dual Core, 20 Threads, LGA 1700 - BX8071512700KF - R$ 1.949,00
# Processador Intel Core i9-11900K 11ª Geração, 3.5 GHz (5.1GHz Turbo), Cache 16MB, Octa Core, LGA1200, Vídeo Integrado - BX8070811900K - R$ 2.799,99
# Processador Intel Core I7 3770, 3.9GHz, Cache 8MB, LGA 1155, Sem Cooler Tray - R$ 342,52
# Processador Intel Core i3-10105F, 3.7GHz (4.4GHz Max Turbo), Cache 6MB, Quad Core, 8 Thread, LGA 1200 - BX8070110105F - R$ 499,99
# Processador Intel Core i7-11700K 11ª Geração, 3.6 GHz (4.9GHz Turbo), Cache 16MB, Octa Core, LGA 1200, Vídeo Integrado - BX8070811700K - R$ 2.599,99
# Processador Intel Core Ultra 7-265K, 5.5GHz, Até 20 Núcleos, Com suporte a PCIe 5.0 e 4.0 e suporte a DDR5 - BX80768265K - R$ 2.899,99
# Processador Intel Core i9-12900K, 3.2GHz (5.2GHz Max Turbo), Cache 30MB, 16 Núcleos, 24 Threads, LGA 1700, Vídeo Integrado - BX8071512900K - R$ 2.499,99
# Processador Intel Core I5-10400F, 2.9GHz (4.3GHz Turbo), Hexa Core, Cache 12MB, LGA 1200 - BX8070110400F - R$ 749,00
# Processador Intel I5-12400, 2.5GHz, Cache 18MB, Hexa Core, 12 Threads, LGA 1700 - BX8071512400 - R$ 1.075,48
# Processador Intel I5-11400F, 2.6GHz, Cache 12MB, Hexa Core, 12 Threads, LGA 1200 - BX8070811400F - R$ 983,95
# Processador Intel Core I5-12600KF 12ª Geração, 3.7GHz, Cache 20MB, 10 Núcleos, 16 Threads, LGA 1700 - BX8071512600KF - R$ 1.299,00
# Processador Intel Core I3-12100, 30GHz, Cache 12MB, 8 Threads, LGA 1700 - Bx8071512100 - R$ 903,74
# Processador Intel Core Ultra 5-245K, 5.2GHz, Até 14 Núcleos, Com suporte a PCIe 5.0 e 4.0 e suporte a DDR5- BX80768245K - R$ 2.699,99
# Processador 1150 Core I7 4790 3,6ghz/8MB S/cooler Tray 4ªg I7-4790 Intel - R$ 411,02
# Processador Intel I3-12100F, 3.3GHz, Cache 12MB, Quad Core, 8 Threads, LGA 1700 - BX8071512100F - R$ 579,00
# Processador Intel 1155 Core I5 2400 3.1ghz/3MB S/ Cooler Tray 2º G I5-2400 - R$ 119,59
# Processador Intel Core i5-9500 Coffee Lake, 3.0GHz, LGA 1151, 9MB, S/ Cooler Tray - BX80684I9500 - R$ 637,99
# Processador Intel Core I3 14100f, 14ª Geração, 3.5 Ghz, 4.7 Ghz Turbo, Cache 12mb Lga 1700, Sem Vídeo - Bx8071514100f - R$ 639,00
# Processador Intel i5-11400 2.6GHz - R$ 1.142,99
# Processador Intel Core I5-8500, 3.0ghz, 9MB, S/cooler Tray - R$ 481,77
# indo para a pagina 3
#
#  coletandos dados da pagina4...
# Elementos encontrados com sucesso!
# Processador Intel I5-6500 + 4 Núcleos +3.6GHZ OEM + Cache6 MB - R$ 305,23
# Processador Intel Core Ultra 7-265KF, 5.5GHz, Até 20 Núcleos, Com suporte a PCIe 5.0 e 4.0 e suporte a DDR5 - BX80768265KF - R$ 2.899,99
# Processador Intel Core i9 10900F 2.80GHz - 5.20GHz Turbo 20MB - R$ 2.357,99
# Processador Intel Core I7 - 14700, 2.1GHz (5.40GHz Max Turbo), Cache 33MB, 28 Threads, LGA 1700 - R$ 2.436,80
# Processador Intel Core I5 14600k 14 Geração, 3.5 Ghz (5.3 Ghz Turbo), Cache, 24MB, LGA1700 - Bx8071514600k - R$ 1.749,00
# Processador Intel Core I9 12900F, 3.80GHz, 16 Core, LGA 1700 - R$ 2.399,00
# Processador Intel I3-2100 / 3.1ghz / 3mb Cache / FcLGA 1155 - R$ 47,63
# Processador Intel Core i9-13900, 5.6GHz Max Turbo, Cache 36MB, 24 Núcleos, 32 Threads, LGA 1700, Vídeo Integrado - BX8071513900 - R$ 3.949,99
# Processador Intel Core Ultra 5-245KF, 5.2GHz, Até 14 Núcleos, Com suporte a PCIe 5.0 e 4.0 e suporte a DDR5 - BX80768245KF - R$ 1.999,99
# Processador Intel Core I7 14700k, 5.60ghz Max Turbo, 20-core, 28-threads, LGA 1700 - R$ 2.769,00
# Processador Intel Core I5-13600K, 2.6GHz, (5.1GHz Max Turbo), Cache 24MB, 20 Threads, LGA 1700 - BX8071513600KI - R$ 1.969,90
# Processador Intel Core i7 11700 2.50GHz - R$ 2.267,99
# Processador Intel Core i3-13100F, 4.5GHz Max Turbo, Cache 12MB, 4 Núcleos, 8 Threads, LGA 1700 - BX8071513100F - R$ 649,99
# Processador Intel Core Ultra 7 265k Arrow Lake 3.9ghz 5.5ghz Turbo 20cores 20threads LGA 1851 Video Integrado - R$ 2.669,00
# Processador Intel Core I3-10105 10ª Geração, 3.70GHz (4.40ghz Turbo), Quad Core, Cache 6MB, 8 Threads, LGA 1200 - BX8070110105 - R$ 699,00
# Processador Intel Core I3 21xx, LGA 1155 - Oem - R$ 68,11
# Processador Intel Core I9-13900kf, Lga 1700, 36MB Cache - Bx8071513900kf - R$ 3.379,00
# Processador Intel Core I5-10400, 2.90GHz (4.3GHz Turbo), Hexa Core, Cache 12MB, LGA 1200 - BX8070110400 - R$ 921,27
# Processador Intel Core i7 i7-2600 3,4GHz 5.0GT/s 8MB LGA1155 - R$ 289,90
# Processador Intel Core I3 81xx 3.6 1151 Oem - R$ 345,72
# indo para a pagina 4
#
#  coletandos dados da pagina5...
# Elementos encontrados com sucesso!
# Processador Intel Core I9 14900k, 14ª Geração, 3.6 GHZ 6.0 GHZ Turbo, Cache 36MB, Intel LGA1700 - BX8071514900K - R$ 3.649,00
# Processador Intel Core I5 13400 Box Lga 1700 10 Cores 16 Threads 20MB Cache - BX8071513400 - R$ 1.289,00
# Processador Intel Core I5 7500, 3.4GHz, Cache 6MB, LGA 1151, Sem Cooler Tray - BX80677I57500 - R$ 386,11
# Processador Intel Core I5 4590, 3.7GHz, Cache 6MB, 1150, Sem Cooler - R$ 179,66
# Processador Core I7 1151 Intel Octa Core I7-9700f - R$ 1.400,87
# Processador Intel I5-9500, 4,40ghz, 9mb Cache - Fclga1151 - R$ 628,18
# Processador Intel Core I7-13700f, 2,10 GHz (5.2GHz Max Turbo) Cache 30MB, 16 Núcleos, 24 Threads, Sem Vídeo Integrado - Bx8071513700f - R$ 2.299,00
# Processador Intel Core I3-2100 Cache 3m 3.10ghz LGA 1155 Oem - R$ 147,97
# Processador Intel Core I9 14900f, 5.80ghz, Max Turbo, 24-core, 32-threads, LGA1700 - R$ 4.209,00
# Processador Intel Core I9-10850K, 3.6GHz (5.2GHz), Cache 20MB, LGA 1200 - BX8070110850K - R$ 2.555,99
# Processador Intel 1150 Core I5 4590, 3.70ghz, 6MB S/cooler, Tray 4ªg, I5-4590 - R$ 166,90
# Processador Intel Core I7-12700K, 3.6GHz (5.0GHz Max Turbo), Cache 25MB, LGA 1700 - BX8071512700K - R$ 1.929,00
# Processador Intel I3-4130, 3.40GHz, Cache 3MB, Dual Core, 4 Threads, FCLGA 1150, OEM - R$ 46,71
# Processador Intel Core i7 10700K 3.80GHz - R$ 2.150,99
# Processador Intel 1151 Core I7 8700 3.7ghz/12mb S/ Cooler Tray 8°g I7-8700 - R$ 989,78
# Processador Intel Core I9 14900, 5.80ghz, Max Turbo, 24-core, 32-threads, LGA1700 - R$ 3.969,00
# Processador Intel Core I7 860 2.88ghz - R$ 193,00
# Processador Intel Core I5-12600K, 3.7GHz (4.9GHz Turbo), Cache 20MB, 10 Núcleos, 16 Threads, LGA 1700 - Bx8071512600k - R$ 1.399,00
# Processador Intel Pentium Dual Core G5500 8ª Geração LGA 1151 - Cm8068403377611 S/cooler S/caixa - R$ 147,12
# Processador Intel Core I9 14900kf, 14ª Geração, 3.6 Ghz (6.0ghz Turbo), Cache 36MB, LGA 1700 - BX8071514900KF - R$ 3.359,00
# indo para a pagina 5
#
#  coletandos dados da pagina6...
# Elementos encontrados com sucesso!
# Processador Intel Core i7 10700KF 3.80GHz - R$ 2.051,99
# Processador Intel Core I5-3470 LGA 1155 3.2ghz 326b770 - R$ 139,90
# Processador Intel Core i5 11400F 2.60GHz - R$ 1.052,99
# Processador Intel Core i9-11900KF, 5.2GHz, Cache 16MB, 8 Núcleos, 16 Threads - R$ 1.769,00
# Processador Intel Core I5-10600KF, 4.1GHz, Cache 12MB, LGA 1200 - BX8070110600KF - R$ 1.259,99
# Processador Intel I7-12700F, 2.1Ghz (4.9Ghz Turbo ), Cache 25MB, 20 Threads, Dual Core, LGA 1700 - BX8071512700F - R$ 1.899,00
# Processador Intel Core I5-11500 11ª Geração, 2.7GHz, Cache 12MB, Hexa Core, 4 Threads, LGA 1200 - BX8070811500 - R$ 2.045,10
# Processador Intel Celeron G6900, 3.40MHz, LGA 1700 - BX80715G6900 - R$ 474,93
# Processador Intel 1151 Core I3 8100 3.6ghz/6mb S/ Cooler Tray 8°g I3-8100 - R$ 267,79
# Processador Intel Sk1151 Core I3 8100 3.6ghz Oem Sem Cooler - R$ 258,00
# Processador Intel Celeron G-5900, 3.40GHz, Dual Core, 2 Threads, FCLGA 1200 - BX80701G5900 - R$ 403,75
# Processador Intel i5-10600K 4.10GHz - R$ 1.448,99
# Processador Intel I5-6500 3.20ghz 6mb LGA 1151 H110(sem Cooler - Oem) - R$ 346,84
# Processador Intel 11700F Core I7 11ª Geração, 2.50GHz, Box - BX8070811700F. - R$ 2.105,99
# Processador Intel Core I9 13900K, 5.80GHz Max Turbo, Cache 36MB, Quad Core, 32 Threads, LGA 1700 - R$ 4.779,00
# Processador Intel Xeon Silver 4310,LGA 4189,2.1ghz,turbo 3.3ghz,Cache 18mb - Bx806894310 - R$ 6.399,39
# Processador Intel G7400 Pentium Gold, 3.70GHz, Cache 6MB, 4 Threads, 1700, Box - BX80715G7400 - R$ 728,10
# Processador Intel I5-2400, 3.10ghz, 6mb Cache - Fclga1155. - R$ 122,18
# Processador Intel I3-6100 3.70ghz 3mb Cache LGA 1151 O&m - R$ 126,45
# Processador Intel Core I5-10400, 2.9GHz, Cache 12MB, LGA 1200 - BX8070110400 - R$ 1.099,00
# indo para a pagina 6
#
#  coletandos dados da pagina7...
# Elementos encontrados com sucesso!
# Processador Intel I7-2600, 3.80ghz, 8mb, Cache - FcLGA - R$ 310,93
# Processador Intel Core I9 13900f, 2.00ghz, 24-core, LGA1700 - R$ 2.999,00
# Intel - Core i7-14700k 14ª Ger. 20 Nuc. 28 Threads - 4,3 Ghz (5,6 Ghz Turbo) Soquete LGA 1700 Proc. De Desktop Desbloqueado - Multi-bx8071514700k - R$ 4.742,36
# Processador Intel Core I7 10700K 10ª Geração, 3.80GHz, Cache 16MB, Octa Core, 16 Threads, LGA 1200 - BX8070110700K - R$ 2.934,55
# Processador Intel Ultra 5 245kf Arrow Lake 4.2ghz 5.2ghz Turbo 14cores 214threads LGA 1851 S/video S/cooler - R$ 2.349,00
# Processador Intel Celeron G5905, 4MB, 3.5ghz, LGA 1200, Bx80701g5905 - R$ 419,00
# Processador Intel Core I9-12900 12ª Geração, 1.8GHz, Cache 30MB, Núcleos 16, Threads 24, LGA 1700 - Bx8071512900 - R$ 3.158,88
# Processador Intel Core i7 10700F 2.90GHz - R$ 1.907,99
# Processador Intel Core I7-4790, 3.60 Ghz, Quad Core Oem, LGA 1150 - R$ 356,90
# Processador Intel Core I7 3770 3ª Geração, 3.40GHz, Quad Core, 8 Threads, FCLGA 1155, OEM - R$ 355,90
# Processador Intel Core I3 7100, 3.9GHz, Cache 3MB, LGA 1151, Sem Cooler Tray - R$ 166,90
# Processador Intel Celeron G5925 10ª Geração, 3.6GHz, Cache 4MB, LGA 1200 - BX80701G5925 - R$ 336,40
# Processador Intel Core I7 6700 Skylake, 3.4GHz (Turbo Max 4.00GHz), Cache 8MB, LGA 1151 - R$ 1.419,00
# Processador Intel Core I3-3220, 3mb, Cache 3.30ghz, 1155 Oem - R$ 147,97
# Processador Intel Core I3-3220, 3ª Geracao, Soquete: 1155 - R$ 107,26
# Processador Intel I3-7100, 3.70ghz, 3mb Cache, Fclga1151 - R$ 155,27
# Processador Intel Core I7-10700KA, 3.8GHz, Cachê 16MB, Octa Core, LGA 1200 - BX8070110700KA - R$ 2.447,99
# Processador Intel Core I5 4690, 4ª Geração, 3.50ghz 6MB Oem 1150 - R$ 161,90
# Processador Intel i5-7500t / 3.30ghz / 6mb Cache / FcLGA 1151 - R$ 348,91
# Processador Intel Core I5 650, 3.2GHz, Cache 4MB, LGA 1156, Sem Cooler Tray - R$ 227,97
# indo para a pagina 7
#
#  coletandos dados da pagina8...
# Elementos encontrados com sucesso!
# Processador Intel Core I3 4130 4ª Geração, 3.40GHz, Cache 3MB, Dual Core, 4 Threads, LGA 1150, OEM - R$ 439,00
# Processador Intel I5-7400, 3.50ghz, 6MB Cache - Fclga1151 - R$ 382,78
# Processador Intel Core i3 3240 Oem - R$ 134,81
# Processador Intel Core I9-12900K, 12ª Geração, 3.2GHz, 5.2GHz Max Turbo, Cache 30MB, Octa Core, 24 Threads, LGA 1700, Vídeo Integrado - BX8071512900K - R$ 3.579,90
# Processador Intel I5-4570 / 3.60ghz / 6mb Cache / FcLGA 1150. - R$ 179,66
# Processador Intel Core I5-11600KF 3.9GHz, 12MB, LGA 1200 - BX8070811600KF I - R$ 1.902,30
# Processador Intel Pentium Gold G6400 - BX80701G6400 - R$ 639,00
# Processador Intel Core I9 14900ks, 6.0ghz Mas Turbo, Cache 36mb, 24 Core, 32 Threads, LGA 1700 - Bx8071514900ks - R$ 7.822,55
# Processador Intel Core I9-12900KF, 3.2GHz, Cache 30MB, Hexa Core, 24 Threads, LGA 1700 - BX8071512900KF - R$ 2.979,00
# Processador I5 3470, 3.20ghz, DDR3, LGA 1155, 3°geração, Oem Intel - R$ 300,10
# Processador Intel Core I5 11600K 11ª Geração, 3.90GHz, Cache 12MB, Hexa Core, 12 Threads, LGA 1200, Intel UHD Graphics 750 - BX8070811600K - R$ 2.286,44
# Processador Intel Xeon E7-8830 SLC3K, 2.13GHz, Cache 24MB, Octa Core, LGA 1567 - R$ 367,11
# Processador 1151 Core I5 8500t 2.10ghz/9mb S/cooler Tray I5-8500t Intel - R$ 453,15
# Processador Intel Core i7-13700f Cache 30mb 5.20ghz 1700 Oem - R$ 2.477,97
# Processador Intel Core I9 11900f Box LGA 1200 16MB Cache S/ Vídeo - Bx8070811900f - R$ 2.499,00
# Processador Intel I7-4770,3,9ghz,8MB Cache - FCLGA1150 - R$ 360,37
# Processador Intel Core I5 6500, 6ª Geração 3.20ghz, 6MB Oem 1151 - R$ 317,90
# Processador Intel Core I3 13100f Box LGA 1700 3.4GHZ 12MB Cache S/ Vídeo - Bx8071513100f - R$ 874,92
# Processador Intel Core I7 13700, 2.10ghz, 16-core, LGA1700 - R$ 3.974,39
# Processador Intel Pentium Gold G6405, 10ª Geração, 4.10GHz, Dual Core, 4 Threads, LGA 1200 - BX80701G6405 - R$ 509,00
# indo para a pagina 8
#
#  coletandos dados da pagina9...
# Elementos encontrados com sucesso!
# Processador Intel I7 12700 12ª Geração, 2.1GHz (Turbo 4.90Ghz), Cache 25MB, Dual Core, 20 Threads, LGA 1700 - BX8071512700 - R$ 2.069,00
# Processador Intel Core i5-11400 2.6ghz, 12mb, LGA 1200 - Bx8070811400 - R$ 1.222,32
# Processador Intel Core I5-7400t 2.4ghz Cache 6mb LGA 1151 Oem - R$ 397,97
# Processador Intel Core I7-11700K, 3.6GHz (4.9GHz Turbo), Cache 16MB, 12 Threads, LGA 1200 - BX8070811700K - R$ 3.204,53
# Processador Intel Core I7 14700kF, 3.4 GHz (5.6GHZ Turbo), Cache 33MB, LGA1700 - Bx8071514700kf - R$ 2.509,00
# Processador Intel Core I5 3470, 2.9GHZ (3.6ghz Turbo), 4 cores, 4 threads, LGA 1155 Oem - R$ 259,20
# Processador Intel Core I3-540 Pull Oem Socket 1156 2 Core 4 Threads Cache 4mb - R$ 47,90
# Processador I7 2600, 3.40ghz, DDR3, LGA 1155, 2°geração Oem Intel - R$ 518,61
# Processador Intel Core I5 6500, 3.2GHz, Cache 6MB, LGA 1151, Sem Cooler Tray - R$ 322,59
# Processador Gamer Core I5-4590, 4 Núc., 3.7ghz, Gráf. Integ. - R$ 260,10
# Processador Intel Core I3-13100, 3.4ghz (4.5ghz Turbo), Lga1700, 12MB Cache, 13ª Geração - R$ 1.045,24
# Processador Intel I3-6100, 3.70GHz, Cache 3MB, Dual Core, 4 Threads, FCLGA 1151, OEM - R$ 286,90
# Processador Intel Core I3-10100F, 3.60GHz (4.30GHz Turbo), Cache 6MB, LGA 1200 - BX8070110100F - R$ 497,78
# Processador Intel Core I7 3770, 3.40GHz, Smart Cache 8MB, Quad Core, 8 Threads, LGA 1155, OEM - R$ 435,38
# Processador Intel Core I5 4570, 3.20GHz, Cache 6MB, LGA 1150 - R$ 179,99
# Processador Intel Core I7 4770 - R$ 623,11
# Processador 1151, Intel Core I3 6100, 3.7ghz/3MB S/coolertray 6º G - I3-6100 - R$ 141,99
# Processador Intel Core I7 6700, 6ª Geração, 3.40ghz, 8MB Oem 1151 - R$ 608,90
# Processador Intel Pentium G2030, 3.0ghz, LGA 1155 - R$ 128,24
# Processador Intel Core I3-10105F, 3.70GHz (4.4GHz Turbo), Cache 6MB, Quad Core, LGA 1200 - BX8070110105F - R$ 521,10
# indo para a pagina 9
#
#  coletandos dados da pagina10...
# Elementos encontrados com sucesso!
# Processador Intel Core I7-10700, 2.90GHz (4.8GHz Turbo), Cache 16MB, LGA 1200 - BX8070110700 - R$ 2.961,62
# Processador Intel Core I3 2120, 3.30GHz, Cache 3MB, LGA 1155 - R$ 170,91
# Processador Intel Celeron G5905, 10ª Geração, 3.50GHz, Cache 4MB, Dual Core, 2 Threads, LGA 1200, Intel UHD Graphics 610 - BX80701G5905 - R$ 332,86
# Processador Intel 1150 Core I3 4160, 3.6ghz/3mb S/cooler Tray 4ªg I3-4160 - R$ 67,97
# Processador Intel Core I5-10600K, 4.1GHz (4.8GHz Max Turbo), Cache 12MB, LGA 1200 - BX8070110600K - R$ 2.044,25
# Processador Intel Core I9-10900F, 2.80GHz, Cache 20MB, 10 Núcleos, 20 Threads, FCLGA 1200, Intel UHD Graphics 630 - R$ 2.546,99
# Processador Intel Core I3-10105f 3.7GHz-4.4GHz, Sem Vídeo - Bx8070110105f - R$ 579,99
# Processador Intel I7-8700 4.6GHz, Cache 12MB, 12 Threads - Fclga1151 - R$ 930,36
# Processador Intel Core I5 2xxx 3.1ghz LGA 1155 Oem - R$ 165,79
# Processador Intel Core I3-12100F 2.9, LGA 1700 - BX8071512100Fi - R$ 737,67
# Processador Intel Core I5-8400 Coffee Lake, Cache 9mb, 2.8ghz (4ghz Max Turbo), LGA 1151 - Oem - R$ 598,54
# Processador Intel Core I5 10400F, 2.90GHz, Cache 12MB, LGA 1200, Sem Cooler Tray - BX8070110400F - R$ 665,42
# Processador Intel Core I3 6100 6ª Geração, 3.70GHz, Cache 3MB, LGA 1151, Skylake - R$ 165,20
# Processador Intel Core Ultra 7 265kf Arrow Lake 3.9ghz 5.5ghz - R$ 2.669,00
# Processador Intel Core I7 6700 3.4ghz 1151 Oem - R$ 846,95
# Processador Intel I7-3770, 3.90ghz, 8mb Cache - Fclga1155. - R$ 358,75
# Processador Intel Core I5 - 10400F, 2.9GHz, Cache 12MB, Hexa Core, 12 Threads, LGA 1200 - R$ 1.099,00
# Processador Intel Core I5 14600k 14 Núcleos 20 Threads 2.6 Ghz LGA 1700 - R$ 3.106,43
# Processador Intel Core I3-7320 Pull Oem Socket LGA 1151 2 Core 4 Threads Cache 4mb - Sem Cooler - R$ 295,13
# Kit 3 Cooler LED 120mm Dex ARGB 120mm - Dx123a - R$ 227,87
# indo para a pagina 10
#
#  coletandos dados da pagina11...
# Elementos encontrados com sucesso!
# Processador Intel Core I9-13900kf, 13ª Geração, 5.8GHz Max Turbo, Cache 36MB, 24 Núcleos, 32 Threads, LGA 1700 - Bx8071513900kf - R$ 4.204,20
# Processador Intel Core I3-6100 Cache 3mb 3.70ghz 1151 Oem - R$ 177,97
# Processador Intel Core Pentium G4400t 2.90ghz 3mb Cache 1151 Oem - R$ 357,97
# Processador Intel Core I7-2600 LGA 1155 Oem - R$ 357,97
# Processador Intel Core I7-4770s Pull Oem Socket LGA 1150 4 Core 8 Threads Cache 8mb - Sem Cooler - R$ 582,53
# Processador Intel Core Ultra 9 285k Series 2 - R$ 6.046,00
# Processador Intel Sk1151 Core I7 6700 3.40ghz Oem Sem Cooler - R$ 637,50
# Processador Intel Celeron G1820, 2.70GHz, Cache 2MB, Dual Core, 2 Threads, LGA 1150 - BX80646G1820 - R$ 376,31
# Processador Intel Core I3-10100f, 4- Core, 8-threads, 3.6ghz (4.3ghz Turbo), Cache 6mb, LGA 1200, Bx80 - R$ 899,00
# Processador Intel Core I3-10100, 4.30GHz, Cache 6MB, LGA 1200 - R$ 905,00
# Processador Intel Core i5-12400f Cache 18mb LGA 1700 Bx8071512400f - R$ 1.299,00
# Processador Intel i5-10400 Comet Lake - R$ 1.097,99
# Processador Intel Core I3 4xxx 3.4ghz 1150 - R$ 88,68
# Processador Intel 1151p Core I3 9100t 3.6ghz 6mb - Oem - R$ 489,90
# Processador Intel Xeon Gold 5418y - LGA 4677 4gen 24 Cores 2.00ghz - 45mb - Tdp: 185w - R$ 27.688,30
# Processador Intel Xeon Gold 5317 - LGA 4189 3gen - 12 Cores - 3.0ghz - 18mb - Tdp: 150w - R$ 15.232,90
# Processador Intel Xeon Gold 5315y - LGA 4189 3gen - 08 Cores 3.60ghz - 12mb - Tdp: 140w - R$ 14.422,02
# Processador Intel Core I3-530 2.93ghz Cache 3mb 1156 Oem. - R$ 147,97
# Processador Intel Core I3-2130 Cache 3mb 3.40ghz 1155 Oem - R$ 147,97
# Processador Intel Core I3-10100f, 4.30 Ghz, Cache 6MB, Threads 8, QuadCore, LGA 1200 - R$ 685,00
# indo para a pagina 11
#
#  coletandos dados da pagina12...
# Elementos encontrados com sucesso!
# Processador Intel Core i5 14400f 14 Geracao 3.5 Ghz (4.7 Ghz Turbo) Cache 20mb 10 Nucleos 16 Threads LGA 1700 Oem - R$ 1.859,87
# Processador Intel Core i5-3340 3.10ghz 1155 3 Geração - R$ 162,58
# Intel® Celeron® G1610 - Lga 1155 - 2.60ghz - Cache 2mb - Tray Sem Cooler - R$ 390,99
# Processador Intel Core I5 3340 - Lga 1155 - 3.30ghz - Cache 6mb - Tray Sem Cooler - Oem - R$ 1.039,99
# Intel® Core™ I7 870 LGA 1156 - 2.93ghz - Cache 8mb - Tray Sem Cooler - R$ 909,99
# Processador Intel I5-14500 LGA 1700 - Bx8071514500 - R$ 2.669,96
# Processador Intel Core I3-2120, 3mb Cache, 3.30ghz, LGA 1155, 2ª Geração. - R$ 119,99
# Processador Intel Sk1200 Core i7 10700t 2.00ghz (max 4.50 Ghz) Oem Sem Cooler - R$ 1.685,88
# Processador Intel Ultra 5 245k Arrow Lake 4.2ghz 5.2ghz Turbo 14cores 14threads LGA 1851 Video Integrado - R$ 2.469,00
# Processador Intel I3 2120 3.3ghtz, 3MB, LGA 1155 - OEM - R$ 112,10
# Processador Intel Xeon Silver 4309y - LGA 4189 3gen - 08 Cores - 2.80ghz - 12mb - Tdp: 105w - R$ 6.269,75
# Processador Intel Core I3-4160 3.6ghz LGA 1150 Oem - R$ 200,00
# Processador Intel Bx807012400f 1700 Core I5 12400f 2.5ghz/ 18MB S/ Cooler Tray - R$ 926,58
# Kit com Processador Intel Core I5 10400f E Pasta Térmica Cooler Master - R$ 789,90
# Processador Intel Core I3-3220 3.30 Ghz 3 Mb Cache 1155 - Importado - R$ 238,50
# Processador I3-10105f 3.7ghz 6mb LGA 1200 Bx8070110105f - R$ 616,00
# Processador Intel Core I7-10700kf, 2.9ghz, LGA 1200 - R$ 2.386,80
# Processador Intel Celeron G3930, LGA 1151 - R$ 598,90
# Processador Gamer Intel Celeron G3900, 2.8GHz, 3MB, 2 Núcleos, 4 Threads, Com Gráfica Integrada - Cm8066201928610 - R$ 637,57
# Processador Intel Core I3-10100 10 Geração, 3.6Ghz, Max Turbo 4.3Ghz, Cache 6MB, LGA 1200 - Bx8070110100 - R$ 1.263,90
# indo para a pagina 12
#
#  coletandos dados da pagina13...
# Elementos encontrados com sucesso!
# Processador Intel Core I5-2400 3.10ghz Cache 6mb LGA 1155 Oem - R$ 177,97
# Processador i3-7100 3.90ghz, 7º Geração - R$ 1.398,78
# Processador Intel Core I5-2320 3.00ghz Cache 6mb LGA 1155 Oem - R$ 157,97
# Fonte Para PC Aerocool 500w Kcas Sem Cabo 80 Plus Bronze - 500w Kcas - R$ 497,87
# Processador Intel Celeron G3930, LGA 1151 - R$ 598,90
# Processador Gamer Intel Core i7-8700 Bx80684i78700 De 6 Núcleos E 4.6ghz De Frequência Com Gráfica Integrada Oem (sem Caixa) - R$ 1.299,00
# Processador Intel Core i3 10100F Comet Lake - R$ 611,99
# Processador Intel Core I7 3770 3.4ghz 1155 Oem - R$ 469,10
# Processador Intel Sk1151 Core i3 9100 3.60ghz Oem Sem Cooler - R$ 310,44
# Processador Intel Core I3 3xxx 3.3ghz Cache 3mb LGA 1155 Oem - R$ 77,11
# Processador Intel Core i7-14700f Cache 33mb 5.4ghz 1700 Oem - R$ 3.147,97
# Processador Intel i7-11700K Rocket Lake 3.60GHz - R$ 2.582,99
# Processador Intel i7-11700KF 3.6GHz - R$ 2.519,99
# Processador Intel Sk1151 Core i5 8500 3.0ghz Oem Sem Cooler - R$ 436,50
# Processador 1700 Core I3 12100 3.3Ghz/12mb S/Cooler Tray 12G I3-12100 Intel - R$ 787,05
# Processador Intel I3-2120, 3.30GHz, Dual Core, 4 Threads, OEM - R$ 98,99
# Processador Intel Core I5-6500 3.2ghz LGA 1151 Oem - R$ 402,26
# Processador Intel Xeon E2124, 3.30GHz, Cache 8MB, Quad Core, LGA 1151, Sem Gráfico - BX80684E2124 - R$ 2.106,99
# Processador Intel I5-10600K Marvel's Avengers Collector's Edition Packaging, Cache 12MB, 4.10GHz (4.80GHz) - BX8070110600KA - R$ 1.664,99
# Processador Intel I7 2600, 3.8GHz, Cache 8MB, LGA 1155, OEM - R$ 399,90
# indo para a pagina 13
#
#  coletandos dados da pagina14...
# Elementos encontrados com sucesso!
# Processador Intel Xeon, 2.1GHz, 46W4363 - E5-2620V2 - R$ 3.160,23
# Processador Intel Celeron 430, 1.80GHz, 512K - R$ 116,04
# Processador Intel Core I7 12700F, 2.1GHz - Bx8071512700fI - R$ 2.635,38
# Erro a tentar avançar para a proxima página Message:
#
# Arquivo 'processadores' salvo com sucesso ({len(df)} produtos capturados!)
